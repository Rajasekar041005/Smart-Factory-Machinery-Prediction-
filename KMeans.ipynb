# %%
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
iris=load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
import pandas as pd
x=iris.data
y=iris.target
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df=df.drop(['sepal length (cm)','sepal width (cm)'], axis=1)
df.head()
# Out:
#    petal length (cm)  petal width (cm)
# 0                1.4               0.2
# 1                1.4               0.2
# 2                1.3               0.2
# 3                1.5               0.2
# 4                1.4               0.2

# %%
model=KMeans(n_clusters=3)
model.fit(df)
# Out:
# KMeans(n_clusters=3)

# %%
df['clusters'] = model.labels_

# %%
df['clusters']=model.predict(df[['petal length (cm)', 'petal width (cm)']])
plt.scatter(df['petal length (cm)'],df['petal width (cm)'],c=df['clusters'],cmap='rainbow')
plt.show()
